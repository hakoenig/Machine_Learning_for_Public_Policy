# %%
import pandas as pd

# %%
# Custom models
import evaluation

# %%
imbalanced_results = pd.read_csv("results.csv")
oversampling_results = pd.read_csv("results_oversampling.csv")
undersampling_results = pd.read_csv("results_undersampling.csv")

imbalanced_results["data"] = "Imbalanced"
oversampling_results["data"] = "oversampling"
undersampling_results["data"] = "undersampling"

all_results = imbalanced_results.append(undersampling_results, ignore_index=True)
#all_results = all_results.append(oversampling_results, ignore_index=True)

all_results["f1_at_1000"] = 2 * ((all_results["p_at_1000"] * all_results["rec_at_1000"]) 
                             / (all_results["p_at_1000"] + all_results["rec_at_1000"]))

all_results["f1_at_2000"] = 2 * ((all_results["p_at_2000"] * all_results["rec_at_2000"]) 
                             / (all_results["p_at_2000"] + all_results["rec_at_2000"]))

# %% [markdown]
# # Which model from which dataset maximizes auc-roc?

# %%
# Max auc-roc by model
all_results.sort_values("auc-roc", ascending=False)[["data", "model_type", "clf", "parameters", 
                                           "train_time", "predict_time", "auc-roc"]].drop_duplicates().head(10)
# Out:
#             data model_type  \
# 2345  Imbalanced         GB
# 2336  Imbalanced         GB
# 1975  Imbalanced         AB
# 2511  Imbalanced         GB
# 91    Imbalanced         RF
# 223   Imbalanced         RF
# 2082  Imbalanced         GB
# 38    Imbalanced         RF
# 113   Imbalanced         RF
# 2279  Imbalanced         GB
#
#                                                     clf  \
# 2345  GradientBoostingClassifier(criterion='friedman...
# 2336  GradientBoostingClassifier(criterion='friedman...
# 1975  AdaBoostClassifier(algorithm='SAMME.R',\n     ...
# 2511  GradientBoostingClassifier(criterion='friedman...
# 91    RandomForestClassifier(bootstrap=True, class_w...
# 223   RandomForestClassifier(bootstrap=True, class_w...
# 2082  GradientBoostingClassifier(criterion='friedman...
# 38    RandomForestClassifier(bootstrap=True, class_w...
# 113   RandomForestClassifier(bootstrap=True, class_w...
# 2279  GradientBoostingClassifier(criterion='friedman...
#
#                                              parameters  train_time  \
# 2345  {'n_estimators': 100, 'learning_rate': 0.1, 's...   20.698193
# 2336  {'n_estimators': 100, 'learning_rate': 0.1, 's...   18.196204
# 1975      {'algorithm': 'SAMME.R', 'n_estimators': 100}    6.123125
# 2511  {'n_estimators': 10, 'learning_rate': 0.5, 'su...    2.854698
# 91    {'min_samples_split': 10, 'n_estimators': 100,...    2.252153
# 223   {'min_samples_split': 10, 'n_estimators': 100,...    1.549831
# 2082  {'n_estimators': 100, 'learning_rate': 0.001, ...   14.136692
# 38    {'min_samples_split': 2, 'n_estimators': 100, ...    1.751771
# 113   {'min_samples_split': 10, 'n_estimators': 100,...    2.454828
# 2279  {'n_estimators': 10, 'learning_rate': 0.1, 'su...    2.319708
#
#       predict_time   auc-roc
# 2345      0.072290  0.867293
# 2336      0.079220  0.865196
# 1975      0.307340  0.861385
# 2511      0.014692  0.860898
# 91        0.122245  0.860759
# 223       0.125107  0.860704
# 2082      0.108299  0.860604
# 38        0.124931  0.860467
# 113       0.120252  0.860438
# 2279      0.016018  0.860352

# %%
all_results.sort_values("auc-roc", ascending=False)[["data", "clf", "parameters"]].drop_duplicates().iloc[0].clf
# Out:
# "GradientBoostingClassifier(criterion='friedman_mse', init=None,\n              learning_rate=0.5, loss='deviance', max_depth=50,\n              max_features=None, max_leaf_nodes=None,\n              min_impurity_split=1e-07, min_samples_leaf=1,\n              min_samples_split=2, min_weight_fraction_leaf=0.0,\n              n_estimators=100, presort='auto', random_state=None,\n              subsample=1.0, verbose=0, warm_start=False)"

# %% [markdown]
# # Which model maximizes f1 score at 1000?

# %%
# Which model & threshold gives us the best f1 score at 1000?
all_results.sort_values("f1_at_1000", ascending=False)[["data","model_type", "clf", "parameters", 
                                                       "train_time", "predict_time", "threshold", "f1_at_1000",
                                                       "p_at_1000", "p_at_2000", "rec_at_1000", 
                                                       "rec_at_2000"]].head(10)
# Out:
#                data model_type  \
# 4778  undersampling         DT
# 494      Imbalanced         DT
# 4838  undersampling         DT
# 4839  undersampling         DT
# 4840  undersampling         DT
# 4841  undersampling         DT
# 4842  undersampling         DT
# 4843  undersampling         DT
# 553      Imbalanced         DT
# 552      Imbalanced         DT
#
#                                                     clf  \
# 4778  DecisionTreeClassifier(class_weight=None, crit...
# 494   DecisionTreeClassifier(class_weight=None, crit...
# 4838  DecisionTreeClassifier(class_weight=None, crit...
# 4839  DecisionTreeClassifier(class_weight=None, crit...
# 4840  DecisionTreeClassifier(class_weight=None, crit...
# 4841  DecisionTreeClassifier(class_weight=None, crit...
# 4842  DecisionTreeClassifier(class_weight=None, crit...
# 4843  DecisionTreeClassifier(class_weight=None, crit...
# 553   DecisionTreeClassifier(class_weight=None, crit...
# 552   DecisionTreeClassifier(class_weight=None, crit...
#
#                                              parameters  train_time  \
# 4778  {'criterion': 'gini', 'max_features': 'log2', ...    0.017165
# 494   {'min_samples_split': 10, 'criterion': 'gini',...    0.034049
# 4838  {'criterion': 'gini', 'max_features': 'sqrt', ...    0.017766
# 4839  {'criterion': 'gini', 'max_features': 'sqrt', ...    0.017766
# 4840  {'criterion': 'gini', 'max_features': 'sqrt', ...    0.017766
# 4841  {'criterion': 'gini', 'max_features': 'sqrt', ...    0.017766
# 4842  {'criterion': 'gini', 'max_features': 'sqrt', ...    0.017766
# 4843  {'criterion': 'gini', 'max_features': 'sqrt', ...    0.017766
# 553   {'min_samples_split': 10, 'criterion': 'gini',...    0.033431
# 552   {'min_samples_split': 10, 'criterion': 'gini',...    0.033431
#
#       predict_time  threshold  f1_at_1000  p_at_1000  p_at_2000  rec_at_1000  \
# 4778      0.011605       0.55         1.0        1.0     0.5700          1.0
# 494       0.008005       0.10         1.0        1.0     0.5845          1.0
# 4838      0.011085       0.70         1.0        1.0     0.6020          1.0
# 4839      0.011085       0.75         1.0        1.0     0.6020          1.0
# 4840      0.011085       0.80         1.0        1.0     0.6020          1.0
# 4841      0.011085       0.85         1.0        1.0     0.6020          1.0
# 4842      0.011085       0.90         1.0        1.0     0.6020          1.0
# 4843      0.011085       0.95         1.0        1.0     0.6020          1.0
# 553       0.007563       0.20         1.0        1.0     0.5845          1.0
# 552       0.007563       0.15         1.0        1.0     0.5845          1.0
#
#       rec_at_2000
# 4778          1.0
# 494           1.0
# 4838          1.0
# 4839          1.0
# 4840          1.0
# 4841          1.0
# 4842          1.0
# 4843          1.0
# 553           1.0
# 552           1.0

# %%
all_results.sort_values("f1_at_1000", ascending=False)[["data", "clf", "parameters"]].drop_duplicates().iloc[0].clf
# Out:
# "DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=100,\n            max_features='log2', max_leaf_nodes=None,\n            min_impurity_split=1e-07, min_samples_leaf=1,\n            min_samples_split=10, min_weight_fraction_leaf=0.0,\n            presort=False, random_state=None, splitter='best')"

# %% [markdown]
# # Which model maximizes f1 score at 2000?

# %%
# Which model & threshold gives us the best f1 score at 2000?
all_results.sort_values("f1_at_2000", ascending=False)[["data","model_type", "clf", "parameters", 
                                                       "train_time", "predict_time", "threshold", "f1_at_2000",
                                                       "p_at_2000", "rec_at_2000"]].head(10)
# Out:
#                data model_type  \
# 4333  undersampling         DT
# 4336  undersampling         DT
# 4332  undersampling         DT
# 4335  undersampling         DT
# 4340  undersampling         DT
# 4339  undersampling         DT
# 4338  undersampling         DT
# 4337  undersampling         DT
# 4334  undersampling         DT
# 3762     Imbalanced         NN
#
#                                                     clf  \
# 4333  DecisionTreeClassifier(class_weight=None, crit...
# 4336  DecisionTreeClassifier(class_weight=None, crit...
# 4332  DecisionTreeClassifier(class_weight=None, crit...
# 4335  DecisionTreeClassifier(class_weight=None, crit...
# 4340  DecisionTreeClassifier(class_weight=None, crit...
# 4339  DecisionTreeClassifier(class_weight=None, crit...
# 4338  DecisionTreeClassifier(class_weight=None, crit...
# 4337  DecisionTreeClassifier(class_weight=None, crit...
# 4334  DecisionTreeClassifier(class_weight=None, crit...
# 3762  MLPClassifier(activation='relu', alpha=0.1, ba...
#
#                                              parameters  train_time  \
# 4333  {'criterion': 'gini', 'max_features': 'log2', ...    0.001773
# 4336  {'criterion': 'gini', 'max_features': 'log2', ...    0.001773
# 4332  {'criterion': 'gini', 'max_features': 'log2', ...    0.001773
# 4335  {'criterion': 'gini', 'max_features': 'log2', ...    0.001773
# 4340  {'criterion': 'gini', 'max_features': 'log2', ...    0.001773
# 4339  {'criterion': 'gini', 'max_features': 'log2', ...    0.001773
# 4338  {'criterion': 'gini', 'max_features': 'log2', ...    0.001773
# 4337  {'criterion': 'gini', 'max_features': 'log2', ...    0.001773
# 4334  {'criterion': 'gini', 'max_features': 'log2', ...    0.001773
# 3762  {'activation': 'relu', 'alpha': 0.1, 'learning...   24.299089
#
#       predict_time  threshold  f1_at_2000  p_at_2000  rec_at_2000
# 4333      0.005664       0.15    0.966141     0.9345          1.0
# 4336      0.005664       0.30    0.966141     0.9345          1.0
# 4332      0.005664       0.10    0.966141     0.9345          1.0
# 4335      0.005664       0.25    0.966141     0.9345          1.0
# 4340      0.005664       0.50    0.966141     0.9345          1.0
# 4339      0.005664       0.45    0.966141     0.9345          1.0
# 4338      0.005664       0.40    0.966141     0.9345          1.0
# 4337      0.005664       0.35    0.966141     0.9345          1.0
# 4334      0.005664       0.20    0.966141     0.9345          1.0
# 3762      0.039504       0.10    0.860399     0.7550          1.0

# %%
all_results.sort_values("f1_at_2000", ascending=False)[["data", "clf", "parameters"]].drop_duplicates().iloc[0].clf
# Out:
# "DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=100,\n            max_features='log2', max_leaf_nodes=None,\n            min_impurity_split=1e-07, min_samples_leaf=1,\n            min_samples_split=10, min_weight_fraction_leaf=0.0,\n            presort=False, random_state=None, splitter='best')"

# %% [markdown]
# # Time is Money...

# %%
# How long did it take to train the models in sec?
all_results.sort_values("train_time", ascending=False)[["data","model_type", "clf", "parameters", 
                                           "train_time", "predict_time", "auc-roc"]].drop_duplicates()
# Out:
#                data model_type  \
# 2220     Imbalanced         GB
# 2441     Imbalanced         GB
# 2232     Imbalanced         GB
# 2460     Imbalanced         GB
# 2012     Imbalanced         AB
# 2201     Imbalanced         GB
# 1918     Imbalanced         AB
# 2430     Imbalanced         GB
# 2676     Imbalanced         GB
# 2655     Imbalanced         GB
# 2697     Imbalanced         GB
# 2389     Imbalanced         GB
# 2603     Imbalanced         GB
# 2177     Imbalanced         GB
# 2394     Imbalanced         GB
# 5778  undersampling         AB
# 2162     Imbalanced         GB
# 2639     Imbalanced         GB
# 5684  undersampling         AB
# 1993     Imbalanced         AB
# 1884     Imbalanced         AB
# 2878     Imbalanced         NN
# 2915     Imbalanced         NN
# 3287     Imbalanced         NN
# 2947     Imbalanced         NN
# 3191     Imbalanced         NN
# 3001     Imbalanced         NN
# 3076     Imbalanced         NN
# 3144     Imbalanced         NN
# 3249     Imbalanced         NN
# ...             ...        ...
# 5510  undersampling        KNN
# 4955  undersampling        KNN
# 5603  undersampling        KNN
# 5045  undersampling        KNN
# 5470  undersampling        KNN
# 5437  undersampling        KNN
# 5546  undersampling        KNN
# 4929  undersampling        KNN
# 5490  undersampling        KNN
# 4664  undersampling         DT
# 4517  undersampling         DT
# 4679  undersampling         DT
# 5377  undersampling        KNN
# 5621  undersampling         AB
# 4478  undersampling         DT
# 4567  undersampling         DT
# 4354  undersampling         DT
# 4523  undersampling         DT
# 4542  undersampling         DT
# 4445  undersampling         DT
# 4379  undersampling         DT
# 4464  undersampling         DT
# 4331  undersampling         DT
# 4254  undersampling         DT
# 4407  undersampling         DT
# 4416  undersampling         DT
# 4295  undersampling         DT
# 4260  undersampling         DT
# 4284  undersampling         DT
# 4341  undersampling         DT
#
#                                                     clf  \
# 2220  GradientBoostingClassifier(criterion='friedman...
# 2441  GradientBoostingClassifier(criterion='friedman...
# 2232  GradientBoostingClassifier(criterion='friedman...
# 2460  GradientBoostingClassifier(criterion='friedman...
# 2012  AdaBoostClassifier(algorithm='SAMME.R',\n     ...
# 2201  GradientBoostingClassifier(criterion='friedman...
# 1918  AdaBoostClassifier(algorithm='SAMME.R',\n     ...
# 2430  GradientBoostingClassifier(criterion='friedman...
# 2676  GradientBoostingClassifier(criterion='friedman...
# 2655  GradientBoostingClassifier(criterion='friedman...
# 2697  GradientBoostingClassifier(criterion='friedman...
# 2389  GradientBoostingClassifier(criterion='friedman...
# 2603  GradientBoostingClassifier(criterion='friedman...
# 2177  GradientBoostingClassifier(criterion='friedman...
# 2394  GradientBoostingClassifier(criterion='friedman...
# 5778  AdaBoostClassifier(algorithm='SAMME.R',\n     ...
# 2162  GradientBoostingClassifier(criterion='friedman...
# 2639  GradientBoostingClassifier(criterion='friedman...
# 5684  AdaBoostClassifier(algorithm='SAMME.R',\n     ...
# 1993  AdaBoostClassifier(algorithm='SAMME.R',\n     ...
# 1884  AdaBoostClassifier(algorithm='SAMME.R',\n     ...
# 2878  MLPClassifier(activation='relu', alpha=0.1, ba...
# 2915  MLPClassifier(activation='relu', alpha=0.1, ba...
# 3287  MLPClassifier(activation='relu', alpha=0.1, ba...
# 2947  MLPClassifier(activation='relu', alpha=0.1, ba...
# 3191  MLPClassifier(activation='relu', alpha=0.1, ba...
# 3001  MLPClassifier(activation='relu', alpha=0.1, ba...
# 3076  MLPClassifier(activation='relu', alpha=0.1, ba...
# 3144  MLPClassifier(activation='relu', alpha=0.1, ba...
# 3249  MLPClassifier(activation='relu', alpha=0.1, ba...
# ...                                                 ...
# 5510  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 4955  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 5603  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 5045  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 5470  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 5437  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 5546  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 4929  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 5490  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 4664  DecisionTreeClassifier(class_weight=None, crit...
# 4517  DecisionTreeClassifier(class_weight=None, crit...
# 4679  DecisionTreeClassifier(class_weight=None, crit...
# 5377  KNeighborsClassifier(algorithm='kd_tree', leaf...
# 5621  AdaBoostClassifier(algorithm='SAMME.R',\n     ...
# 4478  DecisionTreeClassifier(class_weight=None, crit...
# 4567  DecisionTreeClassifier(class_weight=None, crit...
# 4354  DecisionTreeClassifier(class_weight=None, crit...
# 4523  DecisionTreeClassifier(class_weight=None, crit...
# 4542  DecisionTreeClassifier(class_weight=None, crit...
# 4445  DecisionTreeClassifier(class_weight=None, crit...
# 4379  DecisionTreeClassifier(class_weight=None, crit...
# 4464  DecisionTreeClassifier(class_weight=None, crit...
# 4331  DecisionTreeClassifier(class_weight=None, crit...
# 4254  DecisionTreeClassifier(class_weight=None, crit...
# 4407  DecisionTreeClassifier(class_weight=None, crit...
# 4416  DecisionTreeClassifier(class_weight=None, crit...
# 4295  DecisionTreeClassifier(class_weight=None, crit...
# 4260  DecisionTreeClassifier(class_weight=None, crit...
# 4284  DecisionTreeClassifier(class_weight=None, crit...
# 4341  DecisionTreeClassifier(class_weight=None, crit...
#
#                                              parameters   train_time  \
# 2220  {'n_estimators': 100, 'learning_rate': 0.001, ...  1975.834438
# 2441  {'n_estimators': 100, 'learning_rate': 0.1, 's...  1372.701670
# 2232  {'n_estimators': 100, 'learning_rate': 0.001, ...  1148.768571
# 2460  {'n_estimators': 100, 'learning_rate': 0.1, 's...   703.460013
# 2012    {'algorithm': 'SAMME.R', 'n_estimators': 10000}   589.627495
# 2201  {'n_estimators': 100, 'learning_rate': 0.001, ...   550.745391
# 1918      {'algorithm': 'SAMME', 'n_estimators': 10000}   532.266432
# 2430  {'n_estimators': 100, 'learning_rate': 0.1, 's...   484.534586
# 2676  {'n_estimators': 100, 'learning_rate': 0.5, 's...   376.420202
# 2655  {'n_estimators': 100, 'learning_rate': 0.5, 's...   231.814858
# 2697  {'n_estimators': 100, 'learning_rate': 0.5, 's...   145.863668
# 2389  {'n_estimators': 10, 'learning_rate': 0.1, 'su...   141.055072
# 2603  {'n_estimators': 10, 'learning_rate': 0.5, 'su...   129.301825
# 2177  {'n_estimators': 10, 'learning_rate': 0.001, '...   111.943527
# 2394  {'n_estimators': 10, 'learning_rate': 0.1, 'su...   104.041513
# 5778    {'n_estimators': 10000, 'algorithm': 'SAMME.R'}    88.464267
# 2162  {'n_estimators': 10, 'learning_rate': 0.001, '...    87.687914
# 2639  {'n_estimators': 10, 'learning_rate': 0.5, 'su...    87.487555
# 5684      {'n_estimators': 10000, 'algorithm': 'SAMME'}    80.486590
# 1993     {'algorithm': 'SAMME.R', 'n_estimators': 1000}    63.694623
# 1884       {'algorithm': 'SAMME', 'n_estimators': 1000}    57.422470
# 2878  {'activation': 'tanh', 'alpha': 0.0001, 'learn...    56.805713
# 2915  {'activation': 'tanh', 'alpha': 0.0001, 'learn...    51.379246
# 3287  {'activation': 'tanh', 'alpha': 0.1, 'learning...    49.544172
# 2947  {'activation': 'tanh', 'alpha': 0.0001, 'learn...    49.479797
# 3191  {'activation': 'tanh', 'alpha': 0.1, 'learning...    49.471546
# 3001  {'activation': 'tanh', 'alpha': 0.0001, 'learn...    49.398209
# 3076  {'activation': 'tanh', 'alpha': 0.0001, 'learn...    49.316089
# 3144  {'activation': 'tanh', 'alpha': 0.1, 'learning...    49.289861
# 3249  {'activation': 'tanh', 'alpha': 0.1, 'learning...    49.287137
# ...                                                 ...          ...
# 5510  {'algorithm': 'kd_tree', 'n_neighbors': 25, 'w...     0.012677
# 4955  {'algorithm': 'auto', 'n_neighbors': 1, 'weigh...     0.012668
# 5603  {'algorithm': 'kd_tree', 'n_neighbors': 100, '...     0.012663
# 5045  {'algorithm': 'auto', 'n_neighbors': 25, 'weig...     0.012656
# 5470  {'algorithm': 'kd_tree', 'n_neighbors': 10, 'w...     0.012303
# 5437  {'algorithm': 'kd_tree', 'n_neighbors': 5, 'we...     0.012005
# 5546  {'algorithm': 'kd_tree', 'n_neighbors': 50, 'w...     0.011998
# 4929  {'algorithm': 'auto', 'n_neighbors': 1, 'weigh...     0.011912
# 5490  {'algorithm': 'kd_tree', 'n_neighbors': 10, 'w...     0.011841
# 4664  {'criterion': 'gini', 'max_features': 'log2', ...     0.011790
# 4517  {'criterion': 'gini', 'max_features': 'sqrt', ...     0.011609
# 4679  {'criterion': 'gini', 'max_features': 'log2', ...     0.011598
# 5377  {'algorithm': 'kd_tree', 'n_neighbors': 1, 'we...     0.011569
# 5621          {'n_estimators': 1, 'algorithm': 'SAMME'}     0.010656
# 4478  {'criterion': 'gini', 'max_features': 'sqrt', ...     0.010289
# 4567  {'criterion': 'gini', 'max_features': 'log2', ...     0.008791
# 4354  {'criterion': 'gini', 'max_features': 'sqrt', ...     0.008186
# 4523  {'criterion': 'gini', 'max_features': 'log2', ...     0.007460
# 4542  {'criterion': 'gini', 'max_features': 'log2', ...     0.006825
# 4445  {'criterion': 'gini', 'max_features': 'log2', ...     0.006713
# 4379  {'criterion': 'gini', 'max_features': 'sqrt', ...     0.006056
# 4464  {'criterion': 'gini', 'max_features': 'log2', ...     0.005510
# 4331  {'criterion': 'gini', 'max_features': 'log2', ...     0.004604
# 4254  {'criterion': 'gini', 'max_features': 'sqrt', ...     0.004433
# 4407  {'criterion': 'gini', 'max_features': 'sqrt', ...     0.003956
# 4416  {'criterion': 'gini', 'max_features': 'log2', ...     0.003296
# 4295  {'criterion': 'gini', 'max_features': 'log2', ...     0.002736
# 4260  {'criterion': 'gini', 'max_features': 'sqrt', ...     0.002376
# 4284  {'criterion': 'gini', 'max_features': 'sqrt', ...     0.002297
# 4341  {'criterion': 'gini', 'max_features': 'log2', ...     0.001773
#
#       predict_time   auc-roc
# 2220      0.610510  0.832422
# 2441      0.533428  0.836818
# 2232      0.463050  0.644936
# 2460      0.386249  0.831913
# 2012     32.327498  0.846693
# 2201      0.455056  0.848767
# 1918     20.243453  0.854007
# 2430      0.511159  0.546483
# 2676      0.364935  0.615359
# 2655      0.398732  0.514301
# 2697      0.183031  0.811687
# 2389      0.063786  0.758977
# 2603      0.076040  0.608401
# 2177      0.054357  0.641512
# 2394      0.051261  0.563583
# 5778     32.717852  0.836367
# 2162      0.050383  0.739891
# 2639      0.042552  0.642214
# 5684     18.298559  0.848796
# 1993      3.028812  0.856794
# 1884      2.440939  0.853762
# 2878      0.081555  0.828423
# 2915      0.077670  0.837306
# 3287      0.084607  0.835284
# 2947      0.080811  0.841954
# 3191      0.078609  0.837813
# 3001      0.080582  0.838666
# 3076      0.081225  0.838378
# 3144      0.078574  0.838917
# 3249      0.079795  0.838303
# ...            ...       ...
# 5510      8.245948  0.789604
# 4955      3.844487  0.646654
# 5603     12.591305  0.799996
# 5045     11.072348  0.790942
# 5470      7.367704  0.775116
# 5437      7.002453  0.749833
# 5546     11.670868  0.799066
# 4929      3.713394  0.646654
# 5490      7.900788  0.774142
# 4664      0.008764  0.719805
# 4517      0.009192  0.819531
# 4679      0.008495  0.756063
# 5377      6.431372  0.646654
# 5621      0.010930  0.724017
# 4478      0.008407  0.798461
# 4567      0.007372  0.816352
# 4354      0.008713  0.778118
# 4523      0.007220  0.796973
# 4542      0.007302  0.788174
# 4445      0.006967  0.819224
# 4379      0.006951  0.833060
# 4464      0.006543  0.804147
# 4331      0.007930  0.533006
# 4254      0.012931  0.678908
# 4407      0.005764  0.778919
# 4416      0.006029  0.756420
# 4295      0.005922  0.724017
# 4260      0.009424  0.623575
# 4284      0.006090  0.678908
# 4341      0.005664  0.515911
#
# [353 rows x 7 columns]

# %%
# We are only evaluating the time to train and predict on each data set individually
# since the number of training examples were different in each
# time in min

print("----Imbalanced Data-----")
evaluation.print_mean_max(imbalanced_results, "model_type", "train_time")
print()
evaluation.print_mean_max(imbalanced_results, "model_type", "predict_time")

print("\n\n----Undersampled Data-----\n")
evaluation.print_mean_max(undersampling_results, "model_type", "train_time")
print()
evaluation.print_mean_max(undersampling_results, "model_type", "predict_time")

print("\n\n----Oversampled Data-----\n")
evaluation.print_mean_max(oversampling_results, "model_type", "train_time")
print()
evaluation.print_mean_max(oversampling_results, "model_type", "predict_time")
# Out:
# ----Imbalanced Data-----
# Mean values for train_time by model_type is:
# model_type
# GB     3.674252
# AB     2.092771
# NN     0.380912
# RF     0.035437
# LR     0.034066
# KNN    0.005090
# DT     0.001760
# NB     0.001162
# Name: train_time, dtype: float64
#
# Max values for train_time by model_type is:
# model_type
# GB     32.930574
# AB      9.827125
# NN      0.946762
# RF      0.076133
# LR      0.042702
# KNN     0.007146
# DT      0.003748
# NB      0.001162
# Name: train_time, dtype: float64
#
# Mean values for predict_time by model_type is:
# model_type
# KNN    1.350624
# AB     0.097694
# RF     0.002920
# GB     0.002409
# NN     0.001089
# NB     0.000566
# DT     0.000176
# LR     0.000126
# Name: predict_time, dtype: float64
#
# Max values for predict_time by model_type is:
# model_type
# KNN    3.399300
# AB     0.538792
# GB     0.010175
# RF     0.005476
# NN     0.001700
# NB     0.000566
# DT     0.000320
# LR     0.000145
# Name: predict_time, dtype: float64
#
#
# ----Undersampled Data-----
#
# Mean values for train_time by model_type is:
# model_type
# AB     0.311111
# NN     0.070043
# RF     0.006330
# KNN    0.000262
# DT     0.000192
# Name: train_time, dtype: float64
#
# Max values for train_time by model_type is:
# model_type
# AB     1.474404
# NN     0.148329
# RF     0.014684
# KNN    0.001048
# DT     0.000461
# Name: train_time, dtype: float64
#
# Mean values for predict_time by model_type is:
# model_type
# KNN    0.191693
# AB     0.094240
# RF     0.003503
# NN     0.001074
# DT     0.000161
# Name: predict_time, dtype: float64
#
# Max values for predict_time by model_type is:
# model_type
# AB     0.545298
# KNN    0.326215
# RF     0.005792
# NN     0.002332
# DT     0.000380
# Name: predict_time, dtype: float64
#
#
# ----Oversampled Data-----
#
# Mean values for train_time by model_type is:
# model_type
# GB     17.541625
# AB      5.605059
# NN      0.573964
# RF      0.076567
# LR      0.070089
# KNN     0.007870
# DT      0.002934
# NB      0.001535
# Name: train_time, dtype: float64
#
# Max values for train_time by model_type is:
# model_type
# GB     299.225425
# AB      26.135120
# NN       1.441998
# LR       0.176298
# RF       0.158404
# KNN      0.008585
# DT       0.004982
# NB       0.001535
# Name: train_time, dtype: float64
#
# Mean values for predict_time by model_type is:
# model_type
# KNN    0.247944
# AB     0.197159
# RF     0.005104
# GB     0.005048
# NN     0.001354
# NB     0.000695
# DT     0.000252
# LR     0.000051
# Name: predict_time, dtype: float64
#
# Max values for predict_time by model_type is:
# model_type
# AB     1.101916
# KNN    0.581450
# GB     0.023587
# RF     0.009450
# NN     0.002207
# NB     0.000695
# DT     0.000398
# LR     0.000057
# Name: predict_time, dtype: float64
